# %%
import pandas as pd

# %%
df = pd.read_csv('~/Documents/GitHub/capstone-accenture/raw_data/countyPopulationData.csv')

# %%
df
# Out:
#                     county      2013      2014      2015      2016      2017  \
# 0               California  38260787  38596972  38918045  39167117  39358497
# 1           Alameda County   1579593   1607792   1634538   1650950   1660196
# 2            Alpine County      1128      1080      1077      1047      1111
# 3            Amador County     36620     36726     37031     37429     38529
# 4             Butte County    221641    223516    224631    226231    228696
# 5         Calaveras County     44655     44671     44965     45322     45681
# 6            Colusa County     21250     21176     21231     21496     21579
# 7      Contra Costa County   1093401   1108876   1124405   1137268   1145535
# 8         Del Norte County     27816     27175     27190     27382     27351
# 9         El Dorado County    181481    183108    184569    185976    188679
# 10           Fresno County    951514    960567    969488    976830    985238
# 11            Glenn County     27809     27831     27753     27840     27926
# 12         Humboldt County    134403    134494    135102    136290    136507
# 13         Imperial County    176438    177974    178937    180179    181649
# 14             Inyo County     18357     18292     18108     17922     17868
# 15             Kern County    862000    869176    876031    880856    887356
# 16            Kings County    150337    149495    150085    149382    149665
# 17             Lake County     63796     64044     64260     63903     64111
# 18           Lassen County     32129     31664     31256     30721     30920
# 19      Los Angeles County   9992484  10040072  10085416  10105708  10103711
# 20           Madera County    151370    153456    153576    153956    155423
# 21            Marin County    258409    260359    260916    260562    259749
# 22         Mariposa County     17809     17714     17622     17456     17414
# 23        Mendocino County     87054     87225     87107     87285     87576
# 24           Merced County    262026    264419    266353    267628    271096
# 25            Modoc County      9145      9068      9056      8961      8876
# 26             Mono County     14067     14134     14077     14273     14354
# 27         Monterey County    426712    428475    430552    433953    434534
# 28             Napa County    139580    140405    140862    140840    139878
# 29           Nevada County     97938     98572     98676     98913     99367
# 30           Orange County   3104950   3126537   3149280   3164986   3174289
# 31           Placer County    365398    369217    372841    378943    385115
# 32           Plumas County     18895     18622     18427     18665     18660
# 33        Riverside County   2286755   2316162   2345816   2380081   2414964
# 34       Sacramento County   1457341   1474917   1493674   1510987   1527301
# 35       San Benito County     57239     57825     58216     59225     60164
# 36   San Bernardino County   2082738   2099181   2115411   2131960   2150945
# 37        San Diego County   3209768   3248877   3280850   3306089   3321237
# 38    San Francisco County    839572    850750    863010    871512    878040
# 39      San Joaquin County    702046    711579    722271    732809    743296
# 40  San Luis Obispo County    275696    278227    280077    281803    282481
# 41        San Mateo County    748661    757204    765055    767906    768901
# 42    Santa Barbara County    434601    439045    442229    444340    445298
# 43      Santa Clara County   1866425   1891753   1916285   1928368   1932510
# 44       Santa Cruz County    268816    270861    273503    274396    274856
# 45           Shasta County    178397    178844    178314    178571    179384
# 46           Sierra County      3028      2972      2985      2951      3002
# 47         Siskiyou County     43532     43338     43254     43376     43622
# 48           Solano County    423659    429006    433409    438858    443511
# 49           Sonoma County    494073    498560    500863    502547    502469
# 50       Stanislaus County    523451    528015    533211    539255    544717
# 51           Sutter County     94507     94778     95282     95742     96204
# 52           Tehama County     62875     62801     63158     63453     63847
# 53          Trinity County     13427     13128     13094     12828     12726
# 54           Tulare County    452460    455138    457161    459235    462308
# 55         Tuolumne County     53997     53851     53615     53770     53976
# 56          Ventura County    838136    842297    845802    847323    849044
# 57             Yolo County    206292    208398    212037    215627    218477
# 58             Yuba County     73090     73533     74045     74952     76578
#
#         2018      2019
# 0   39461588  39512223
# 1    1666756   1671329
# 2       1089      1129
# 3      39405     39752
# 4     230339    219186
# 5      45698     45905
# 6      21418     21547
# 7    1150519   1153526
# 8      27740     27812
# 9     190746    192843
# 10    991950    999101
# 11     27967     28393
# 12    136244    135558
# 13    181523    181215
# 14     17946     18039
# 15    893758    900202
# 16    151382    152940
# 17     64317     64386
# 18     30618     30573
# 19  10073906  10039107
# 20    156882    157327
# 21    259662    258826
# 22     17405     17203
# 23     87401     86749
# 24    274151    277680
# 25      8800      8841
# 26     14403     14444
# 27    433950    434061
# 28    138789    137744
# 29     99508     99755
# 30   3175973   3175692
# 31    392330    398329
# 32     18741     18807
# 33   2445789   2470546
# 34   1538746   1552058
# 35     61467     62808
# 36   2166753   2180085
# 37   3333861   3338330
# 38    880696    881549
# 39    752491    762148
# 40    283354    283111
# 41    768681    766573
# 42    445780    446499
# 43   1932337   1927852
# 44    273841    273213
# 45    179709    180080
# 46      2997      3005
# 47     43550     43539
# 48    445725    447643
# 49    498643    494336
# 50    548126    550660
# 51     96348     96971
# 52     64018     65084
# 53     12567     12285
# 54    464589    466195
# 55     54387     54478
# 56    848142    846006
# 57    220118    220500
# 58     77557     78668

# %%
df.columns = ('county', '2013', '2014', '2015', '2016', '2017', '2018', '2019')

# %%
df = df.drop([59, 60, 61, 62, 63])

# %%
df.county = df.county.str.replace(", California", "")
df.county = df.county.str.replace(".", "")

# %%
df["2013"] = df["2013"].str.replace(",", "")

# %%
df["2014"] = df["2014"].str.replace(",", "")

# %%
df["2015"] = df["2015"].str.replace(",", "")

# %%
df["2016"] = df["2016"].str.replace(",", "")

# %%
df["2017"] = df["2017"].str.replace(",", "")

# %%
df["2018"] = df["2018"].str.replace(",", "")
df["2019"] = df["2019"].str.replace(",", "")

# %%
df.melt(id_vars=["county"], 
        var_name="Year", 
        value_name="Population")
# Out:
#               county  Year Population
# 0         California  2013   38260787
# 1     Alameda County  2013    1579593
# 2      Alpine County  2013       1128
# 3      Amador County  2013      36620
# 4       Butte County  2013     221641
# ..               ...   ...        ...
# 408    Tulare County  2019     466195
# 409  Tuolumne County  2019      54478
# 410   Ventura County  2019     846006
# 411      Yolo County  2019     220500
# 412      Yuba County  2019      78668
#
# [413 rows x 3 columns]

# %%
df.to_csv("~/Documents/Github/capstone-accenture/clean_data/countyPopulationData.csv", index=False)

# %%
housing = pd.read_csv('~/Downloads/countyHousingDensity.csv')

# %%
housing
# Out:
#                                            Unnamed: 0        2013        2014  \
# 0                                          California  13,827,794  13,906,691
# 1                         .Alameda County, California     589,352     592,396
# 2                          .Alpine County, California       1,765       1,764
# 3                          .Amador County, California      18,241      18,239
# 4                           .Butte County, California      96,989      97,517
# ..                                                ...         ...         ...
# 59  Note: The estimates are based on the 2010 Cens...         NaN         NaN
# 60                                Suggested Citation:         NaN         NaN
# 61  Annual Estimates of Housing Units for Counties...         NaN         NaN
# 62    Source: U.S. Census Bureau, Population Division         NaN         NaN
# 63                             Release Date: May 2020         NaN         NaN
#
#           2015        2016        2017        2018        2019
# 0   13,985,614  14,075,264  14,172,348  14,275,353  14,366,336
# 1      595,760     600,467     605,974     615,030     622,922
# 2        1,766       1,769       1,770       1,778       1,782
# 3       18,249      18,274      18,318      18,452      18,625
# 4       98,073      98,692      99,438     100,074      86,209
# ..         ...         ...         ...         ...         ...
# 59         NaN         NaN         NaN         NaN         NaN
# 60         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN
# 62         NaN         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN         NaN
#
# [64 rows x 8 columns]

# %%
housing.columns = ('city', '2013', '2014', '2015', '2016', '2017', '2018', '2019')

# %%
housing = housing.drop([59,60,61,62,63])

# %%
housing.city = housing.city.str.replace(", California", "")

# %%
housing["2013"] = housing["2013"].str.replace(",", "")
housing["2014"] = housing["2014"].str.replace(",", "")
housing["2015"] = housing["2015"].str.replace(",", "")
housing["2016"] = housing["2016"].str.replace(",", "")
housing["2017"] = housing["2017"].str.replace(",", "")
housing["2018"] = housing["2018"].str.replace(",", "")
housing["2019"] = housing["2019"].str.replace(",", "")

# %%
housing.to_csv("~/Desktop/capstone-project/capstone-accenture/countyHousingDensity.csv", index=False)
